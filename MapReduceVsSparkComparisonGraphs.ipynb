# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
### -  CarrierDelay
# create data
df2 = pd.DataFrame([['1st', 28.62, 7.54], ['2nd', 16.88, 13.54], ['3rd', 13.389, 4.12], ['4th', 14.799, 1.42], ['5th', 11.262, 1.44]],columns=['Iterations', 'HiveSQL', 'SparkSQL'])
df2.columns
  
# plot grouped bar chart
df2.plot(x='Iterations',kind='bar',stacked=False,title='CarrierDelay')
# Out:
# <AxesSubplot:title={'center':'CarrierDelay'}, xlabel='Iterations'>

# %%
### -  NAS Delay
# create data
df2 = pd.DataFrame([['1st', 11.615, 17.61], ['2nd', 11.682, 15.54], ['3rd', 11.455, 1.44], ['4th', 13.452, 1.41], ['5th', 10.939, 1.39]],columns=['Iterations', 'HiveSQL', 'SparkSQL'])
df2.columns
  
# plot grouped bar chart
df2.plot(x='Iterations',kind='bar',stacked=False,title='NAS Delay')
# Out:
# <AxesSubplot:title={'center':'NAS Delay'}, xlabel='Iterations'>

# %%
### -  Weather Delay
# create data
df2 = pd.DataFrame([['1st', 12.033, .867], ['2nd', 12.1, 1.4], ['3rd', 11.957, .857], ['4th', 11.312, 1.45], ['5th', 10.788, .864]],columns=['Iterations', 'HiveSQL', 'SparkSQL'])
df2.columns
  
# plot grouped bar chart
df2.plot(x='Iterations',kind='bar',stacked=False,title='Weather Delay')
# Out:
# <AxesSubplot:title={'center':'Weather Delay'}, xlabel='Iterations'>

# %%
### -  Delayed flight
# create data
df2 = pd.DataFrame([['1st', 12.24, .866], ['2nd', 11.032, .833], ['3rd', 11.339, .844], ['4th', 11.084, .94], ['5th', 12.147, .848]],columns=['Iterations', 'HiveSQL', 'SparkSQL'])
df2.columns
  
# plot grouped bar chart
df2.plot(x='Iterations',kind='bar',stacked=False,title='Delayed Flight')
# Out:
# <AxesSubplot:title={'center':'Delayed Flight'}, xlabel='Iterations'>

# %%
### -  Security delay
# create data
df2 = pd.DataFrame([['1st', 11.394, .885], ['2nd', 14.948, .94], ['3rd', 11.136, .995], ['4th', 13.837, .85], ['5th', 12.813, .848]],columns=['Iterations', 'HiveSQL', 'SparkSQL'])
df2.columns
  
# plot grouped bar chart
df2.plot(x='Iterations',kind='bar',stacked=False,title='Security delay flight')
# Out:
# <AxesSubplot:title={'center':'Security delay flight'}, xlabel='Iterations'>

# %%
### -  Security delay
# create data
df2 = pd.DataFrame([['Carrier Delay', 16.99, 5.61], ['Nas Delay', 11.82, 7.48], ['Weather delay', 11.638, 1.08], ['Delayed flight', 13.837, .85], ['Security delay', 12.82, .90]],columns=['Category', 'HiveSQL', 'SparkSQL'])
df2.columns
  
# plot grouped bar chart
df2.plot(x='Category',kind='bar',stacked=False)
# Out:
# <AxesSubplot:xlabel='Category'>
